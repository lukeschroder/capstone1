# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import scipy.stats as stats
import pyspark as ps
from pyspark.sql.types import *
import pyspark.sql.functions as F
import sys
plt.style.use('ggplot')

# %%
spark = ps.sql.SparkSession.builder \
            .master("local[4]") \
            .appName("df lecture") \
            .getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# # Pull in artist feautures data
#
#     -create spark df as df_artist_features

# %%
print(sys.path)
# Out:
# ['/home/jovyan/work/Documents/dsi/Capstone1/notebooks', '/tmp/spark-9c928b4c-7349-4d74-9ffb-4aa52773418b/userFiles-3eb641d1-f308-473e-bcf2-a7499b44584f', '/usr/local/spark/python/lib/py4j-0.10.9-src.zip', '/usr/local/spark/python', '/home/jovyan/work/Documents/dsi/Capstone1/notebooks', '/opt/conda/lib/python38.zip', '/opt/conda/lib/python3.8', '/opt/conda/lib/python3.8/lib-dynload', '', '/opt/conda/lib/python3.8/site-packages', '/opt/conda/lib/python3.8/site-packages/IPython/extensions', '/home/jovyan/.ipython']

# %%
dba = pd.read_csv('/home/jovyan/work/Documents/dsi/Capstone1/data/data_by_artist.csv')
dba.head()
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.598500
# 1                          "Cats" 1983 Broadway Cast      0.862538
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.470100  267072.000000  0.376203          0.010261  0.283050
# 1      0.441731  287280.000000  0.406808          0.081158  0.315215
# 2      0.348286  328920.000000  0.286571          0.024593  0.325786
# 3      0.425074  262890.962963  0.245770          0.073587  0.275481
# 4      0.467143  270436.142857  0.488286          0.009400  0.195000
#
#     loudness  speechiness       tempo   valence  popularity  key  mode  count
# 0 -14.434300     0.209150  114.128800  0.358320   38.200000    5     1     10
# 1 -10.690000     0.176212  103.044154  0.268865   31.538462    5     1     26
# 2 -15.230714     0.118514   77.375857  0.354857   34.571429    0     1      7
# 3 -15.639370     0.123200   88.667630  0.372030   34.407407    0     1     27
# 4 -10.236714     0.098543  122.835857  0.482286   42.000000    5     1      7

# %%
df_artist_features = spark.read.csv('/home/jovyan/work/Documents/dsi/Capstone1/data/data_by_artist.csv',header=True).cache()
df_artist_features.printSchema()
print("line count: {}".format(df_artist_features.count()))
df_artist_features.show()
# Out:
# root
#  |-- artists: string (nullable = true)
#  |-- acousticness: string (nullable = true)
#  |-- danceability: string (nullable = true)
#  |-- duration_ms: string (nullable = true)
#  |-- energy: string (nullable = true)
#  |-- instrumentalness: string (nullable = true)
#  |-- liveness: string (nullable = true)
#  |-- loudness: string (nullable = true)
#  |-- speechiness: string (nullable = true)
#  |-- tempo: string (nullable = true)
#  |-- valence: string (nullable = true)
#  |-- popularity: string (nullable = true)
#  |-- key: string (nullable = true)
#  |-- mode: string (nullable = true)
#  |-- count: string (nullable = true)
#
# line count: 32539
# +--------------------+-------------------+-------------------+------------------+-------------------+--------------------+-------------------+-------------------+-------------------+------------------+-------------------+------------------
# |'In The Heights' ...| 0.6266666666666666|              0.547|387293.66666666674|0.39266666666666666|                 0.0|               0.26| -8.348666666666666|             0.3121|171.16766666666663| 0.5093333333333333|              52.0|  5|   1|    3|
# |'Legally Blonde' ...|              0.598| 0.6296666666666667|208493.66666666663| 0.5099999999999999|                 0.0|              0.251|-10.526666666666667| 0.6076666666666667| 95.09033333333336| 0.5163333333333333| 51.66666666666666|  2|   1|    3|
# |        'Til Tuesday|         0.10555625|           0.557125|          255213.5|            0.61225|        0.0233002525|0.12758750000000002|          -9.638125|            0.03215|103.08025000000002|           0.532625|            33.875|  0|   1|   16|
# |           ((( O )))|              0.847|               0.41|          311837.0|0.16899999999999998|0.003270000000000...|              0.117|            -11.422|             0.0485|            89.494|              0.208|              66.0|  3|   1|    2|
# |(Con La Participa...| 0.5379999999999999|              0.731|          361440.0|              0.794|            2.39e-05|             0.0736|             -4.182|             0.0408| 88.00299999999999|              0.873|              42.0|  5|   1|    2|
# |                (EM)|              0.446|              0.462|          221832.0|              0.542|              0.0956|               0.97|             -9.161|             0.0308|            99.403|              0.547|               4.0|  6|   1|    4|
# +--------------------+-------------------+-------------------+------------------+-------------------+--------------------+-------------------+-------------------+-------------------+------------------+-------------------+------------------+---+----+-----+
# only showing top 20 rows

# %% [markdown]
# # Pull in million-playlist data
#
#     -Playlist level data as df_playlistsdf_features
#
#     -Track level data as df_tracks

# %%
spark = (ps.sql.SparkSession.builder 
        .master("local[4]") 
        .appName("sparkSQL exercise") 
        .getOrCreate()
        )
sc = spark.sparkContext

# %%
million_list = spark.read.json('/home/jovyan/work/Documents/dsi/Capstone1/data/mpd.slice.0-999.json',multiLine=True).cache()

# prints the schema
million_list.printSchema()

# some functions are still valid
print("line count: {}".format(million_list.count()))

# show the table in a oh-so-nice format
million_list.show()
# Out:
# root
#  |-- info: struct (nullable = true)
#  |    |-- generated_on: string (nullable = true)
#  |    |-- slice: string (nullable = true)
#  |    |-- version: string (nullable = true)
#  |-- playlists: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- collaborative: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- duration_ms: long (nullable = true)
#  |    |    |-- modified_at: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- num_albums: long (nullable = true)
#  |    |    |-- num_artists: long (nullable = true)
#  |    |    |-- num_edits: long (nullable = true)
#  |    |    |-- num_followers: long (nullable = true)
#  |    |    |-- num_tracks: long (nullable = true)
#  |    |    |-- pid: long (nullable = true)
#  |    |    |-- tracks: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- album_name: string (nullable = true)
#  |    |    |    |    |-- album_uri: string (nullable = true)
#  |    |    |    |    |-- artist_name: string (nullable = true)
#  |    |    |    |    |-- artist_uri: string (nullable = true)
#  |    |    |    |    |-- duration_ms: long (nullable = true)
#  |    |    |    |    |-- pos: long (nullable = true)
#  |    |    |    |    |-- track_name: string (nullable = true)
#  |    |    |    |    |-- track_uri: string (nullable = true)
#
# line count: 1
# +--------------------+--------------------+
# |                info|           playlists|
# +--------------------+--------------------+
# |[2017-12-03 08:41...|[[false,, 1153241...|
# +--------------------+--------------------+

# %%
million_list_lists = million_list.select("info", F.explode("playlists").alias('playlist'))
#million_exploded = million_list_lists.select("playlist", F.explode("playlist"))
million_list_lists.show()
# Out:
# +--------------------+--------------------+
# |        false|       null|   16403398| 1509321600|               abby |        60|         40|       36|            2|        72| 10|[[Stoney, spotify...|[2017-12-03 08:41...|[false,, 16403398...|
# |        false|       null|   35655891| 1365379200|                VIBE|       117|         99|       16|            1|       134| 11|[[Hôtel Costes 12...|[2017-12-03 08:41...|[false,, 35655891...|
# |        false|       null|    1981349| 1481587200|               relax|         9|          9|        3|            1|         9| 12|[[Yael Naim, spot...|[2017-12-03 08:41...|[false,, 1981349,...|
# |        false|       null|    3039124| 1509062400|               sleep|        13|         12|        5|            1|        13| 13|[[Safe Haven, spo...|[2017-12-03 08:41...|[false,, 3039124,...|
# |        false|       null|   25837498| 1382572800|               90's |        79|         61|        3|            1|       103| 14|[[311, spotify:al...|[2017-12-03 08:41...|[false,, 25837498...|
# |        false|       null|    1818256| 1432684800|           New Songs|         5|          3|        3|            1|         7| 15|[[Sylvan Esso, sp...|[2017-12-03 08:41...|[false,, 1818256,...|
# |        false|       null|   24695913| 1491696000|          slow hands|        94|         81|       45|            1|       105| 16|[[Home of the Str...|[2017-12-03 08:41...|[false,, 24695913...|
# |        false|       null|   17627215| 1465430400|      Mom's playlist|        69|         61|       11|            1|        79| 17|[[Hozier, spotify...|[2017-12-03 08:41...|[false,, 17627215...|
# |        false|       null|   15917464| 1507334400|               SARAH|        66|         55|       18|            1|        68| 18|[[Gravity, spotif...|[2017-12-03 08:41...|[false,, 15917464...|
# |        false|       null|   21627256| 1430956800|          melancholy|        82|         70|       54|            1|        85| 19|[[Baby Darling Do...|[2017-12-03 08:41...|[false,, 21627256...|
# +-------------+-----------+-----------+-----------+--------------------+----------+-----------+---------+-------------+----------+---+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
million_exploded_song = df_playlists.select("collaborative","description","duration_ms","name","pid",  F.explode("tracks").alias('tracks'))
playlist_tracks = million_exploded_song.select("tracks.*","*").withColumnRenamed("name","playlist_name") \
                                                                .withColumnRenamed("duration_ms","playlist_duration_ms") \
                                                                .withColumnRenamed("description","playlist_description") \
                                                                .withColumnRenamed("collaborative","playlist_collaborative")
playlist_tracks.show()
# Out:
# +--------------------+--------------------+------------------+--------------------+--------------------+---+--------------------+--------------------+----------------------+--------------------+--------------------+-------------+---+--------------------+
# |          album_name|           album_uri|       artist_name|          artist_uri|playlist_duration_ms|pos|          track_name|           track_uri|playlist_collaborative|playlist_description|playlist_duration_ms|playlist_name|pid|              tracks|
# +--------------------+--------------------+------------------+--------------------+--------------------+---+--------------------+--------------------+----------------------+--------------------+--------------------+-------------+---+--------------------+
# |        The Cookbook|spotify:album:6vV...|     Missy Elliott|spotify:artist:2w...|              226863|  0|Lose Control (fea...|spotify:track:0Ua...|                 false|                null|            11532414|   Throwbacks|  0|[The Cookbook, sp...|
# |         In The Zone|spotify:album:0z7...|    Britney Spears|spotify:artist:26...|              198800|  1|               Toxic|spotify:track:6I9...|                 false|                null|            11532414|   Throwbacks|  0|[In The Zone, spo...|
# |Dangerously In Lo...|spotify:album:25h...|           Beyoncé|spotify:artist:6v...|              235933|  2|       Crazy In Love|spotify:track:0Wq...|                 false|                null|            11532414|   Throwbacks|  0|[Dangerously In L...|
# |               B'Day|spotify:album:3MJ...|           Beyoncé|spotify:artist:6v...|              210453| 18|Check On It - fea...|spotify:track:6d8...|                 false|                null|            11532414|   Throwbacks|  0|[B'Day, spotify:a...|
# |The Writing's On ...|spotify:album:283...|   Destiny's Child|spotify:artist:1Y...|              230200| 19|    Jumpin', Jumpin'|spotify:track:4pm...|                 false|                null|            11532414|   Throwbacks|  0|[The Writing's On...|
# +--------------------+--------------------+------------------+--------------------+--------------------+---+--------------------+--------------------+----------------------+--------------------+--------------------+-------------+---+--------------------+
# only showing top 20 rows

# %%
df_tracks = playlist_tracks.drop('tracks')
df_tracks.show()
# Out:
# +--------------------+--------------------+------------------+--------------------+--------------------+---+--------------------+--------------------+----------------------+--------------------+--------------------+-------------+---+
# |          album_name|           album_uri|       artist_name|          artist_uri|playlist_duration_ms|pos|          track_name|           track_uri|playlist_collaborative|playlist_description|playlist_duration_ms|playlist_name|pid|
# +--------------------+--------------------+------------------+--------------------+--------------------+---+--------------------+--------------------+----------------------+--------------------+--------------------+-------------+---+
# |        The Cookbook|spotify:album:6vV...|     Missy Elliott|spotify:artist:2w...|              226863|  0|Lose Control (fea...|spotify:track:0Ua...|                 false|                null|            11532414|   Throwbacks|  0|
# |         In The Zone|spotify:album:0z7...|    Britney Spears|spotify:artist:26...|              198800|  1|               Toxic|spotify:track:6I9...|                 false|                null|            11532414|   Throwbacks|  0|
# |Dangerously In Lo...|spotify:album:25h...|           Beyoncé|spotify:artist:6v...|              235933|  2|       Crazy In Love|spotify:track:0Wq...|                 false|                null|            11532414|   Throwbacks|  0|
# |           Justified|spotify:album:6QP...| Justin Timberlake|spotify:artist:31...|              267266|  3|      Rock Your Body|spotify:track:1AW...|                 false|                null|            11532414|   Throwbacks|  0|
# |            Hot Shot|spotify:album:6Nm...|            Shaggy|spotify:artist:5E...|              227600|  4|        It Wasn't Me|spotify:track:1lz...|                 false|                null|            11532414|   Throwbacks|  0|
# |         Confessions|spotify:album:0vO...|             Usher|spotify:artist:23...|              250373|  5|               Yeah!|spotify:track:0XU...|                 false|                null|            11532414|   Throwbacks|  0|
# |         Confessions|spotify:album:1RM...|             Usher|spotify:artist:23...|              223440|  6|              My Boo|spotify:track:68v...|                 false|                null|            11532414|   Throwbacks|  0|
# |                 PCD|spotify:album:5x8...|The Pussycat Dolls|spotify:artist:6w...|              225560|  7|             Buttons|spotify:track:3Bx...|                 false|                null|            11532414|   Throwbacks|  0|
# |The Writing's On ...|spotify:album:283...|   Destiny's Child|spotify:artist:1Y...|              271333|  8|         Say My Name|spotify:track:7H6...|                 false|                null|            11532414|   Throwbacks|  0|
# |Speakerboxxx/The ...|spotify:album:1Us...|           OutKast|spotify:artist:1G...|              235213|  9|Hey Ya! - Radio M...|spotify:track:2Pp...|                 false|                null|            11532414|   Throwbacks|  0|
# |               Loose|spotify:album:2yb...|     Nelly Furtado|spotify:artist:2j...|              242293| 10|         Promiscuous|spotify:track:2ga...|                 false|                null|            11532414|   Throwbacks|  0|
# |Right Where You W...|spotify:album:602...|   Jesse McCartney|spotify:artist:2H...|              211693| 11|Right Where You W...|spotify:track:4Y4...|                 false|                null|            11532414|   Throwbacks|  0|
# |      Beautiful Soul|spotify:album:2gi...|   Jesse McCartney|spotify:artist:2H...|              214226| 12|      Beautiful Soul|spotify:track:1Hw...|                 false|                null|            11532414|   Throwbacks|  0|
# |Departure - Recha...|spotify:album:2tD...|   Jesse McCartney|spotify:artist:2H...|              216880| 13|             Leavin'|spotify:track:20O...|                 false|                null|            11532414|   Throwbacks|  0|
# |              Cassie|spotify:album:0j1...|            Cassie|spotify:artist:27...|              192213| 14|              Me & U|spotify:track:7k6...|                 false|                null|            11532414|   Throwbacks|  0|
# |                  21|spotify:album:4cV...|           Omarion|spotify:artist:0f...|              256426| 15|             Ice Box|spotify:track:1Bv...|                 false|                null|            11532414|   Throwbacks|  0|
# |              Let Go|spotify:album:7h6...|     Avril Lavigne|spotify:artist:0p...|              204000| 16|           Sk8er Boi|spotify:track:4om...|                 false|                null|            11532414|   Throwbacks|  0|
# |         Chris Brown|spotify:album:49g...|       Chris Brown|spotify:artist:7b...|              229866| 17|             Run It!|spotify:track:7xY...|                 false|                null|            11532414|   Throwbacks|  0|
# |               B'Day|spotify:album:3MJ...|           Beyoncé|spotify:artist:6v...|              210453| 18|Check On It - fea...|spotify:track:6d8...|                 false|                null|            11532414|   Throwbacks|  0|
# |The Writing's On ...|spotify:album:283...|   Destiny's Child|spotify:artist:1Y...|              230200| 19|    Jumpin', Jumpin'|spotify:track:4pm...|                 false|                null|            11532414|   Throwbacks|  0|
# +--------------------+--------------------+------------------+--------------------+--------------------+---+--------------------+--------------------+----------------------+--------------------+--------------------+-------------+---+
# only showing top 20 rows

# %% [markdown]
# # Create temp table objects for SQL capabilities

# %%
df_playlists.createOrReplaceTempView("playlists")
df_tracks.createOrReplaceTempView("tracks")
df_artist_features.createOrReplaceTempView("artist_features")

# %% [markdown]
# # Exploratory Queries

# %% [markdown]
# ## <font color='gray'> Playlist level data</font>

# %%
playlist_count = spark.sql("""
                           SELECT COUNT(pid)
                           FROM playlists
                           """)
playlist_count.show()
# Out:
# +----------+
# |count(pid)|
# +----------+
# |      1000|
# +----------+

# %% [markdown]
# ## <font color='gray'> Tracks level data</font>

# %%
tracks_count_bytrack = spark.sql("""
                           SELECT artist_name
                           ,track_name
                           ,COUNT(*) AS count
                           FROM tracks
                           GROUP BY artist_name
                           ,track_name
                           ORDER BY count DESC
                           """)
tracks_count_bytrack.show()
# Out:
# +----------------+--------------------+-----+
# |     artist_name|          track_name|count|
# +----------------+--------------------+-----+
# |           Drake|           One Dance|   55|
# |  Kendrick Lamar|             HUMBLE.|   52|
# |            DRAM|Broccoli (feat. L...|   50|
# |The Chainsmokers|              Closer|   46|
# |     Post Malone|     Congratulations|   44|
# |The Chainsmokers|   Don't Let Me Down|   42|
# |           Drake|             Jumpman|   39|
# |The Chainsmokers|               Roses|   39|
# |        Big Sean|         Bounce Back|   39|
# |            KYLE|iSpy (feat. Lil Y...|   39|
# |           Migos|Bad and Boujee (f...|   38|
# |          Future|            Mask Off|   38|
# |    Lil Uzi Vert|       XO TOUR Llif3|   37|
# |       Desiigner|               Panda|   36|
# |     Post Malone|       White Iverson|   36|
# |      Kanye West|         Gold Digger|   35|
# |           Flume|   Never Be Like You|   35|
# |           Aminé|            Caroline|   35|
# |    Travis Scott|          goosebumps|   35|
# |   Justin Bieber|               Sorry|   35|
# +----------------+--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ## <font color='gray'> Features df.write.csv('mycsv.csv')level data</font>

# %%
features_count = spark.sql("""
                            SELECT DISTINCT COUNT(artists) as count
                            FROM artist_features
                            """)
features_count.show()
# Out:
# +-----+
# |count|
# +-----+
# |32539|
# +-----+

# %% [markdown]
# ## Creating, Saving and Reading artist_features_join dataset

# %%
artist_features_join = spark.sql("""
                                SELECT t.artist_name
                                ,AVG(a.acousticness) AS acousticness
                                ,AVG(a.danceability) AS danceability
                                ,AVG(a.energy) AS energy
                                ,AVG(a.instrumentalness) AS instrumentalness
                                ,AVG(a.liveness) AS liveness
                                ,AVG(a.loudness) AS loudness
                                ,AVG(a.speechiness) AS speechiness
                                ,AVG(a.tempo) AS avg_tempo
                                ,AVG(a.valence) AS valence
                                ,AVG(a.popularity) AS popularity
                                ,COUNT(DISTINCT t.track_name) AS unique_tracks_in_playlists
                                ,COUNT(ALL t.track_name) AS total_tracks_in_playlists
                                FROM tracks t
                                JOIN artist_features a
                                ON t.artist_name = a.artists
                                GROUP BY t.artist_name
                                ORDER BY t.artist_name ASC
                                """)

artist_features_join.show(15)
# Out:
# +--------------------+--------------------+-------------------+-------------------+--------------------+-------------------+-------------------+--------------------+------------------+-------------------+------------------+--------------------------+-------------------------+
# |         artist_name|        acousticness|       danceability|             energy|    instrumentalness|           liveness|           loudness|         speechiness|         avg_tempo|            valence|        popularity|unique_tracks_in_playlists|total_tracks_in_playlists|
# +--------------------+--------------------+-------------------+-------------------+--------------------+-------------------+-------------------+--------------------+------------------+-------------------+------------------+--------------------------+-------------------------+
# |         $uicideBoy$| 0.15463710144927542| 0.7785507246376814| 0.6258695652173915| 0.02472047565217391|0.20922318840579707| -6.553898550724632|  0.1499855072463768|117.67908695652173| 0.2427724637681159| 65.33333333333333|                         5|                        5|
# |'In The Heights' ...|  0.6266666666666666|              0.547|0.39266666666666666|                 0.0|               0.26| -8.348666666666666|              0.3121|171.16766666666663| 0.5093333333333333|              52.0|                         2|                        2|
# |        'Til Tuesday|          0.10555625|           0.557125|            0.61225|        0.0233002525|0.12758750000000002|          -9.638125|             0.03215|103.08025000000002|           0.532625|            33.875|                         1|                        2|
# |          (Hed) P.E.|0.005993333333333334| 0.5936666666666667| 0.8956666666666667|3.376666666666666...|0.12819999999999998|-5.1629999999999985| 0.09523333333333334|           110.925|              0.413| 45.33333333333334|                         1|                        1|
# |              *NSYNC| 0.18485504242424242| 0.6002525252525254| 0.6972222222222219|0.001292984646464...| 0.2273434343434344| -6.386555555555558|0.054446464646464646|116.97407070707078| 0.5569898989898988| 46.04040404040404|                        12|                       35|
# |                 +44|             3.67E-4|              0.416|              0.967|                 0.0|             0.0632|             -2.289|               0.109|           171.032|              0.431|              53.0|                         1|                        1|
# |...And You Will K...|0.008409999999999999|              0.255|              0.858|             3.55E-4|              0.513|             -5.085|              0.0694|           144.653|              0.237|              36.0|                         1|                        1|
# |  10 Ft. Ganja Plant|               0.195| 0.7859999999999999|              0.752|               0.867|             0.0427|             -2.859|              0.0387|           136.578|              0.925|              49.0|                         1|                        1|
# |            10 Years|0.001100666666666...|              0.452| 0.7863333333333332|1.185599999999999...|0.10583333333333332| -4.567333333333333|0.047200000000000006|145.14166666666668|0.25800000000000006| 57.66666666666664|                         5|                        7|
# |      10,000 Maniacs| 0.18243352941176474| 0.5880000000000001| 0.5565058823529412|0.002059093529411764|0.20626470588235293|-13.217764705882347| 0.03901764705882353|115.60611764705885| 0.6161764705882353|37.882352941176464|                         1|                        1|
# |101 Strings Orche...|  0.5975607692307693|0.27042307692307693| 0.3878461538461538|  0.7503076923076922|0.18619230769230774|-13.582384615384614|0.037592307692307696|103.51823076923075| 0.3158769230769231| 20.92307692307693|                         9|                        9|
# |                10cc|  0.2105388888888889| 0.5635000000000002| 0.5707777777777775|0.006783127777777779|0.14880000000000002|-10.387944444444448| 0.06513333333333332|120.38427777777777| 0.5782777777777776| 40.72222222222222|                         2|                        7|
# |                 112| 0.14438511627906978| 0.6880232558139536| 0.5291395348837209|1.833372093023256E-4|0.14031627906976754| -7.723255813953489| 0.10937674418604652|115.96383720930235| 0.5811860465116279| 49.16279069767442|                        12|                       19|
# |            2 Chainz| 0.09684032258064514| 0.7767903225806455| 0.6258548387096776|1.932796774193548E-4|0.18474032258064502|-6.1421290322580635| 0.23188548387096794|125.71295161290321|0.47893870967741947|61.435483870967765|                        34|                      100|
# |         2 LIVE CREW|0.056752090909090926| 0.8787272727272728| 0.6760000000000004|0.012531776363636364| 0.3782363636363636|-11.481909090909092| 0.19647272727272733|126.90122727272728| 0.6045909090909093| 34.81818181818182|                         1|                        1|
# +--------------------+--------------------+-------------------+-------------------+--------------------+-------------------+-------------------+--------------------+------------------+-------------------+------------------+--------------------------+-------------------------+
# only showing top 15 rows

# %%
af_join = artist_features_join.toPandas()
print(af_join.info())
af_join.to_csv('/home/jovyan/work/Documents/dsi/Capstone1/data/artist_features_join.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4787 entries, 0 to 4786
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   artist_name                 4787 non-null   object
#  1   acousticness                4787 non-null   float64
#  2   danceability                4787 non-null   float64
#  3   energy                      4787 non-null   float64
#  4   instrumentalness            4787 non-null   float64
#  5   liveness                    4787 non-null   float64
#  6   loudness                    4787 non-null   float64
#  7   speechiness                 4787 non-null   float64
#  8   avg_tempo                   4787 non-null   float64
#  9   valence                     4787 non-null   float64
#  10  popularity                  4787 non-null   float64
#  11  unique_tracks_in_playlists  4787 non-null   int64
#  12  total_tracks_in_playlists   4787 non-null   int64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 486.3+ KB
# None

# %%
df_feature_join = spark.read.csv('/home/jovyan/work/Documents/dsi/Capstone1/data/artist_features_join.csv',header=True).cache()
df_feature_join.printSchema()
print("line count: {}".format(df_feature_join.count()))
df_feature_join.show()
# Out:
# root
#  |-- artist_name: string (nullable = true)
#  |-- acousticness: string (nullable = true)
#  |-- danceability: string (nullable = true)
#  |-- energy: string (nullable = true)
#  |-- instrumentalness: string (nullable = true)
#  |-- liveness: string (nullable = true)
#  |-- loudness: string (nullable = true)
#  |-- speechiness: string (nullable = true)
#  |-- avg_tempo: string (nullable = true)
#  |-- valence: string (nullable = true)
#  |-- popularity: string (nullable = true)
#  |-- unique_tracks_in_playlists: string (nullable = true)
#  |-- total_tracks_in_playlists: string (nullable = true)
#
# line count: 4787
# +--------------------+--------------------+-------------------+-------------------+--------------------+-------------------+-------------------+--------------------
# |            2 Chainz| 0.09684032258064514| 0.7767903225806455| 0.6258548387096776|0.000193279677419...|0.18474032258064502|-6.1421290322580635| 0.23188548387096794|125.71295161290321|0.47893870967741947|61.435483870967765|                        34|                      100|
# |         2 LIVE CREW|0.056752090909090926| 0.8787272727272728| 0.6760000000000004|0.012531776363636364| 0.3782363636363636|-11.481909090909092| 0.19647272727272733|126.90122727272728| 0.6045909090909093| 34.81818181818182|                         1|                        1|
# |         2 Unlimited|             0.03058|             0.6985|            0.92225|         0.006455925|            0.08355|          -11.51875|            0.059275|           130.971| 0.7639999999999999|              55.0|                         1|                        1|
# |           21 Savage| 0.13250868750000006| 0.7913125000000003| 0.5948750000000004| 0.03706835208333334|0.15883750000000016| -6.604958333333333| 0.26102291666666666|125.87227083333343| 0.3775916666666669| 70.16666666666669|                        28|                      116|
# |                2NE1|0.007670000000000002| 0.8190000000000001| 0.8440000000000002|             0.00834|              0.056|-3.7390000000000003|               0.038|           127.997|              0.687|              64.0|                         5|                        8|
# |                2Pac| 0.12875520622568112| 0.7766692607003883| 0.7034046692607009| 0.00798961093385213| 0.2223914396887161| -7.226571984435806|  0.2193486381322956|107.64694941634247| 0.6047198443579759| 48.64202334630348|                        84|                      142|
# |        3 Doors Down|0.021503117948717957| 0.5143333333333336| 0.7790512820512819|0.000808764358974...|0.14189743589743592| -5.738205128205129| 0.03495641025641027|124.36546153846159| 0.4197692307692309|52.974358974358964|                         9|                       33|
# +--------------------+--------------------+-------------------+-------------------+--------------------+-------------------+-------------------+--------------------+------------------+-------------------+------------------+--------------------------+-------------------------+
# only showing top 20 rows

# %%
pd_feature_join = df_feature_join.toPandas()
ints = list(pd_feature_join.columns)
ints = ints[1:]
pd_feature_join[ints] = pd_feature_join[ints].apply(pd.to_numeric)
pd_feature_join['artist_name'] = pd_feature_join['artist_name'].apply(lambda x: r'x')
pd_feature_join = pd_feature_join.convert_dtypes()
sorted_feature_join = pd_feature_join.sort_values('total_tracks_in_playlists',ascending=False)
top_s = sorted_feature_join.loc[:,['artist_name','acousticness','danceability','energy','valence','avg_tempo','popularity','total_tracks_in_playlists']].copy()
top_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4787 entries, 1220 to 4786
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   artist_name                4787 non-null   string
#  1   acousticness               4787 non-null   Float64
#  2   danceability               4787 non-null   Float64
#  3   energy                     4787 non-null   Float64
#  4   valence                    4787 non-null   Float64
#  5   avg_tempo                  4787 non-null   Float64
#  6   popularity                 4787 non-null   Float64
#  7   total_tracks_in_playlists  4787 non-null   Int64
# dtypes: Float64(6), Int64(1), string(1)
# memory usage: 369.3 KB

# %%
bars = list(top_s.columns)[1:5]

colors = ['red','blue','orange','purple','gray','green','brown','teal','yellow']
fig, ax = plt.subplots(3,3,figsize=(18,12))
for idx, axs in enumerate(ax.flatten()):
    heights = np.array(top_s.iloc[idx,1:5])
    axs.bar(bars,heights,color=colors[idx],edgecolor="black",alpha=.7)
    axs.set_title(top_s.iloc[idx,0])

# %%
def one_dim_scatterplot(data, ax, jitter=0.2, **options):
    ## why jitter? especially for bootstraping later
    if jitter:
        jitter = np.random.uniform(-jitter, jitter, size=data.shape)
    else:
        jitter = np.repeat(0.0, len(data))
    ax.scatter(data, jitter, **options)
    ax.yaxis.set_ticklabels([])
    ax.set_ylim([0, 1])
    ax.tick_params(axis='both', which='major', labelsize=15)

# %%
labels = list(top_s.columns)[1:]
fig, ax = plt.subplots(7,1, figsize=(24, 30))
for idx, axs in enumerate(ax.flatten()):
    feature = np.array(top_s.iloc[:,idx+1])
    one_dim_scatterplot(feature, axs)
    axs.set_title(labels[idx])

# %%
df_feature_join1 = df_feature_join.withColumn("popularity",F.col("popularity").cast("FloatType"))
df_feature_join1.printSchema()
df_feature_join.createOrReplaceTempView("feature_join")
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-104-d7956f440811> in <module>
# ----> 1 df_feature_join1 = df_feature_join.withColumn("popularity",F.col("popularity").cast("FloatType"))
#       2 df_feature_join1.printSchema()
#       3 df_feature_join.createOrReplaceTempView("feature_join")
#
# /usr/local/spark/python/pyspark/sql/column.py in cast(self, dataType)
#     593         """
#     594         if isinstance(dataType, basestring):
# --> 595             jc = self._jc.cast(dataType)
#     596         elif isinstance(dataType, DataType):
#     597             from pyspark.sql import SparkSession
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     132                 # Hide where the exception came from that shows a non-Pythonic
#     133                 # JVM exception message.
# --> 134                 raise_from(converted)
#     135             else:
#     136                 raise
#
# /usr/local/spark/python/pyspark/sql/utils.py in raise_from(e)
#
# ParseException:
# DataType floattype is not supported.(line 1, pos 0)
#
# == SQL ==
# FloatType
# ^^^

# %%
select = spark.sql("""
                    SELECT artist_name
                    ,popularity
                    FROM feature_join
                    WHERE popularity < 0.0000000001
                    GROUP BY artist_name
                    """)
select.show
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-97-c5ded8baf632> in <module>
# ----> 1 select = spark.sql("""
#       2                     SELECT artist_name
#       3                     ,popularity
#       4                     FROM feature_join
#       5                     WHERE popularity < 0.0000000001
#
# /usr/local/spark/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     647         [Row(f1=1, f2=u'row1'), Row(f1=2, f2=u'row2'), Row(f1=3, f2=u'row3')]
#     648         """
# --> 649         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     650
#     651     @since(2.0)
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     132                 # Hide where the exception came from that shows a non-Pythonic
#     133                 # JVM exception message.
# --> 134                 raise_from(converted)
#     135             else:
#     136                 raise
#
# /usr/local/spark/python/pyspark/sql/utils.py in raise_from(e)
#
# AnalysisException: expression 'feature_join.`popularity`' is neither present in the group by, nor is it an aggregate function. Add to group by or wrap in first() (or first_value) if you don't care which value you get.;;
# Aggregate [artist_name#2179], [artist_name#2179, popularity#2189]
# +- Filter (cast(popularity#2189 as double) < cast(1E-10 as double))
#    +- SubqueryAlias feature_join
#       +- Relation[artist_name#2179,acousticness#2180,danceability#2181,energy#2182,instrumentalness#2183,liveness#2184,loudness#2185,speechiness#2186,avg_tempo#2187,valence#2188,popularity#2189,unique_tracks_in_playlists#2190,total_tracks_in_playlists#2191] csv
